# %% [markdown]
# # 📄 Aula 2 — Docling: Ingestão Inteligente de PDFs Jurídicos
# ## MBA em RAG & CAG Aplicados a Direito e Segurança Pública
#
# **Objetivo:** Dominar a ingestão de PDFs complexos com Docling, comparar com PyPDF2 e integrar ao pipeline RAG.
#
# **Duração estimada:** 75 minutos
#
# ---
# ### Diagrama da Aula
# ```
# PDF Jurídico Complexo
#         │
#         ├──▶ PyPDF2 (baseline)     ──▶ texto plano sem estrutura
#         │
#         └──▶ Docling (avançado)    ──▶ Markdown estruturado
#                   │                        + tabelas extraídas
#                   │                        + metadados de seção
#                   │                        + suporte a OCR
#                   │
#                   └──▶ LangChain Documents com metadados ricos
# ```
#
# > **ABNT:** IBM RESEARCH. *Docling: An Efficient Document Conversion Library*. GitHub, 2024.

# %% [markdown]
# ## 🔧 Célula 1 — Instalação
#
# O Docling tem dependências pesadas (modelos de layout). A instalação pode levar **3–5 minutos** no Colab.
#
# > ⚠️ **Atenção:** O Docling baixa modelos (~500MB) na primeira execução. Isso é normal.

# %%
# ============================================================
# INSTALAÇÃO DO DOCLING E DEPENDÊNCIAS
# ============================================================

# Docling: biblioteca principal de ingestão
# %pip install docling easyocr

# PyPDF2: para comparação (baseline)
# %pip install PyPDF2

# Dependências adicionais
# %pip install langchain langchain-community
# %pip install requests  

# Fallback de PDFs
# %pip install -q reportlab 

print("✅ Instalação concluída!")
print()
print("📦 Versões instaladas:")
import importlib.metadata
import docling
import PyPDF2

print(f"   docling: {importlib.metadata.version('docling')}")
print(f"   PyPDF2:  {PyPDF2.__version__}")
# Out:
# Requirement already satisfied: docling in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (2.95.0)
# Requirement already satisfied: easyocr in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (1.7.2)
# Requirement already satisfied: docling-slim==2.95.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (2.95.0)
# Requirement already satisfied: certifi>=2024.7.4 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (2026.2.25)
# Requirement already satisfied: docling-core<3.0.0,>=2.73.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (2.77.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (1.2.0)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (1.6.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (2.14.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (2.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.32.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (2.32.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (4.67.3)
# Requirement already satisfied: accelerate<2,>=1.0.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (1.13.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (4.14.3)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (0.7.1)
# Requirement already satisfied: docling-ibm-models<4,>=3.13.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (3.13.2)
# Requirement already satisfied: docling-parse<6.0.0,>=5.3.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (5.11.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (0.28.1)
# Requirement already satisfied: huggingface-hub<2,>=0.23 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (1.6.0)
# Requirement already satisfied: lxml<7.0.0,>=4.0.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (6.1.1)
# Requirement already satisfied: marko<3.0.0,>=2.1.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (2.2.2)
# Requirement already satisfied: numpy<3.0.0,>=1.24.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (2.4.3)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (3.1.5)
# Requirement already satisfied: pillow<13.0.0,>=10.0.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (12.1.1)
# Requirement already satisfied: polyfactory>=2.22.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (3.3.0)
# Requirement already satisfied: pylatexenc<3.0,>=2.10 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (2.10)
# Requirement already satisfied: pypdfium2!=4.30.1,<6.0.0,>=4.30.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (5.8.0)
# Requirement already satisfied: python-docx<2.0.0,>=1.1.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (1.2.0)
# Requirement already satisfied: python-pptx<2.0.0,>=1.0.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (1.0.2)
# Requirement already satisfied: rapidocr<4.0.0,>=3.8 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (3.8.1)
# Requirement already satisfied: rich>=13.0.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (14.3.3)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (1.4.1)
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (1.17.1)
# Requirement already satisfied: torch<3.0.0,>=2.2.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (2.2.2)
# Requirement already satisfied: torchvision<1,>=0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (0.17.2)
# Collecting typer<0.22.0,>=0.12.5 (from docling-slim[standard]==2.95.0->docling)
#   Using cached typer-0.21.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: websockets<17.0,>=14.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-slim[standard]==2.95.0->docling) (16.0)
# Requirement already satisfied: packaging>=20.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from accelerate<2,>=1.0.0->docling-slim[standard]==2.95.0->docling) (26.0)
# Requirement already satisfied: psutil in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from accelerate<2,>=1.0.0->docling-slim[standard]==2.95.0->docling) (7.2.2)
# Requirement already satisfied: pyyaml in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from accelerate<2,>=1.0.0->docling-slim[standard]==2.95.0->docling) (6.0.3)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from accelerate<2,>=1.0.0->docling-slim[standard]==2.95.0->docling) (0.7.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling-slim[standard]==2.95.0->docling) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling-slim[standard]==2.95.0->docling) (4.15.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-core<3.0.0,>=2.73.0->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (4.26.0)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-core<3.0.0,>=2.73.0->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (1.1.0)
# Requirement already satisfied: tabulate<0.11.0,>=0.9.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-core<3.0.0,>=2.73.0->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (0.10.0)
# Requirement already satisfied: pandas<4.0.0,>=2.1.4 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from docling-core<3.0.0,>=2.73.0->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (3.0.1)
# Requirement already satisfied: latex2mathml<4.0.0,>=3.77.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-core<3.0.0,>=2.73.0->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (3.81.0)
# Requirement already satisfied: semchunk<4.0.0,>=2.2.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-core[chunking]<3.0.0,>=2.73.0; extra == "standard"->docling-slim[standard]==2.95.0->docling) (3.2.5)
# Requirement already satisfied: tree-sitter<0.27.0,>=0.25.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-core[chunking]<3.0.0,>=2.73.0; extra == "standard"->docling-slim[standard]==2.95.0->docling) (0.25.2)
# Requirement already satisfied: tree-sitter-python>=0.23.6 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-core[chunking]<3.0.0,>=2.73.0; extra == "standard"->docling-slim[standard]==2.95.0->docling) (0.25.0)
# Requirement already satisfied: tree-sitter-c>=0.23.4 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-core[chunking]<3.0.0,>=2.73.0; extra == "standard"->docling-slim[standard]==2.95.0->docling) (0.24.2)
# Requirement already satisfied: tree-sitter-javascript>=0.23.1 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-core[chunking]<3.0.0,>=2.73.0; extra == "standard"->docling-slim[standard]==2.95.0->docling) (0.25.0)
# Requirement already satisfied: tree-sitter-typescript>=0.23.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-core[chunking]<3.0.0,>=2.73.0; extra == "standard"->docling-slim[standard]==2.95.0->docling) (0.23.2)
# Requirement already satisfied: transformers<6.0.0,>=4.34.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-core[chunking]<3.0.0,>=2.73.0; extra == "standard"->docling-slim[standard]==2.95.0->docling) (4.57.6)
# Requirement already satisfied: jsonlines<5.0.0,>=3.1.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from docling-ibm-models<4,>=3.13.0->docling-slim[standard]==2.95.0->docling) (4.0.0)
# Requirement already satisfied: anyio in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28->docling-slim[standard]==2.95.0->docling) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28->docling-slim[standard]==2.95.0->docling) (1.0.9)
# Requirement already satisfied: idna in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28->docling-slim[standard]==2.95.0->docling) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28->docling-slim[standard]==2.95.0->docling) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from huggingface-hub<2,>=0.23->docling-slim[standard]==2.95.0->docling) (3.25.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from huggingface-hub<2,>=0.23->docling-slim[standard]==2.95.0->docling) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from huggingface-hub<2,>=0.23->docling-slim[standard]==2.95.0->docling) (1.3.2)
# Requirement already satisfied: attrs>=19.2.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from jsonlines<5.0.0,>=3.1.0->docling-ibm-models<4,>=3.13.0->docling-slim[standard]==2.95.0->docling) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.73.0->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.73.0->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.73.0->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (0.30.0)
# Requirement already satisfied: et-xmlfile in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from openpyxl<4.0.0,>=3.1.5->docling-slim[standard]==2.95.0->docling) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from pandas<4.0.0,>=2.1.4->docling-core<3.0.0,>=2.73.0->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.3.0->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (1.2.2)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from python-pptx<2.0.0,>=1.0.2->docling-slim[standard]==2.95.0->docling) (3.2.9)
# Requirement already satisfied: pyclipper>=1.2.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from rapidocr<4.0.0,>=3.8->docling-slim[standard]==2.95.0->docling) (1.4.0)
# Requirement already satisfied: opencv_python>=4.5.1.48 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from rapidocr<4.0.0,>=3.8->docling-slim[standard]==2.95.0->docling) (4.13.0.92)
# Requirement already satisfied: six>=1.15.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from rapidocr<4.0.0,>=3.8->docling-slim[standard]==2.95.0->docling) (1.17.0)
# Requirement already satisfied: Shapely!=2.0.4,>=1.7.1 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from rapidocr<4.0.0,>=3.8->docling-slim[standard]==2.95.0->docling) (2.1.2)
# Requirement already satisfied: omegaconf in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from rapidocr<4.0.0,>=3.8->docling-slim[standard]==2.95.0->docling) (2.3.0)
# Requirement already satisfied: colorlog in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from rapidocr<4.0.0,>=3.8->docling-slim[standard]==2.95.0->docling) (6.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.2->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.2->docling-slim==2.95.0->docling-slim[standard]==2.95.0->docling) (2.6.3)
# Requirement already satisfied: mpire[dill] in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from semchunk<4.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.73.0; extra == "standard"->docling-slim[standard]==2.95.0->docling) (2.10.2)
# Requirement already satisfied: sympy in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-slim[standard]==2.95.0->docling) (1.14.0)
# Requirement already satisfied: networkx in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-slim[standard]==2.95.0->docling) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from torch<3.0.0,>=2.2.2->docling-slim[standard]==2.95.0->docling) (3.1.6)
# Collecting huggingface-hub<2,>=0.23 (from docling-slim[standard]==2.95.0->docling)
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: regex!=2019.12.17 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from transformers<6.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.73.0; extra == "standard"->docling-slim[standard]==2.95.0->docling) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from transformers<6.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.73.0; extra == "standard"->docling-slim[standard]==2.95.0->docling) (0.22.2)
# Requirement already satisfied: click>=8.0.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from typer<0.22.0,>=0.12.5->docling-slim[standard]==2.95.0->docling) (8.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from typer<0.22.0,>=0.12.5->docling-slim[standard]==2.95.0->docling) (0.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from typer<0.22.0,>=0.12.5->docling-slim[standard]==2.95.0->docling) (1.5.4)
# Requirement already satisfied: opencv-python-headless in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from easyocr) (4.13.0.92)
# Requirement already satisfied: scikit-image in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from easyocr) (0.26.0)
# Requirement already satisfied: python-bidi in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from easyocr) (0.6.10)
# Requirement already satisfied: ninja in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from easyocr) (1.13.0)
# Requirement already satisfied: faker>=5.0.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from polyfactory>=2.22.2->docling-slim[standard]==2.95.0->docling) (40.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from rich>=13.0.0->docling-slim[standard]==2.95.0->docling) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from rich>=13.0.0->docling-slim[standard]==2.95.0->docling) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.0.0->docling-slim[standard]==2.95.0->docling) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from jinja2->torch<3.0.0,>=2.2.2->docling-slim[standard]==2.95.0->docling) (3.0.3)
# Requirement already satisfied: multiprocess>=0.70.15 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from mpire[dill]->semchunk<4.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.73.0; extra == "standard"->docling-slim[standard]==2.95.0->docling) (0.70.19)
# Requirement already satisfied: dill>=0.4.1 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from multiprocess>=0.70.15->mpire[dill]->semchunk<4.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.73.0; extra == "standard"->docling-slim[standard]==2.95.0->docling) (0.4.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from omegaconf->rapidocr<4.0.0,>=3.8->docling-slim[standard]==2.95.0->docling) (4.9.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from scikit-image->easyocr) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from scikit-image->easyocr) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from scikit-image->easyocr) (0.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from sympy->torch<3.0.0,>=2.2.2->docling-slim[standard]==2.95.0->docling) (1.3.0)
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# Using cached typer-0.21.2-py3-none-any.whl (56 kB)
# Installing collected packages: huggingface-hub, typer
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.6.0
#     Not uninstalling huggingface-hub at /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages, outside environment /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag
#     Can't uninstall 'huggingface_hub'. No files were found to uninstall.
#   Attempting uninstall: typer━━━━━━━━━━━━━━━━━━━ 0/2 [huggingface-hub]
#     Found existing installation: typer 0.24.1 0/2 [huggingface-hub]
#     Not uninstalling typer at /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages, outside environment /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag
#     Can't uninstall 'typer'. No files were found to uninstall.[huggingface-hub]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [typer]32m1/2 [typer]
# Successfully installed huggingface-hub-0.36.2 typer-0.21.2
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: PyPDF2 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (3.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (1.3.1)
# Requirement already satisfied: langchain-community in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langchain) (1.4.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langchain) (1.2.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (4.1.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.0->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (4.12.1)
# Requirement already satisfied: certifi in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from langchain-community) (2.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.6.3)
# Requirement already satisfied: greenlet>=1 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from requests) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gustavoaranha/PycharmProjects/mba-ia/05-visao-computacional/aula-02/venv-gen-ai/lib/python3.11/site-packages (from requests) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ✅ Instalação concluída!
#
# 📦 Versões instaladas:
#    docling: 2.95.0
#    PyPDF2:  3.0.1

# %% [markdown]
# ## 📥 Célula 2 — Datasets PDF da Aula 2 (uso de PDFs reais)
#
# Em vez de gerar PDFs sintéticos com `reportlab`, este exemplo usa os **dois PDFs reais** que ficam em `aula2/datasets/`:
#
# | Arquivo | Tipo | Comportamento esperado |
# |---|---|---|
# | `Manual_DPCA_atualizado.pdf` | PDF **digital** com texto extraível | Docling extrai estrutura sem OCR (rápido) |
# | `Laudo.pdf` | PDF com **imagem de texto** (escaneado) | Docling precisa de `do_ocr=True` (lento, mas funciona) |
#
# Esses são os datasets oficiais da Aula 2 — também usados pelo `LAB1_Docling_Ingestao_Avancada.ipynb`. Se você rodar este notebook fora do projeto (sem a pasta `datasets/`), o código abaixo gera um fallback sintético para que o exemplo continue executável.

# %%
# ============================================================
# PREPARAÇÃO: Usar os 2 PDFs reais do dataset da Aula 2
#   - Manual_DPCA_atualizado.pdf  → PDF digital (texto extraível)
#   - Laudo.pdf                    → PDF com imagem de texto (precisa OCR)
# Localização: aula-02/datasets/ (relativo ao notebook em aula-02/exemplos/)
# ============================================================
from pathlib import Path
import os

# Caminho do dataset
DATASET_DIR = Path("../datasets").resolve()
if not DATASET_DIR.exists():
    DATASET_DIR = Path.cwd().parent / "datasets"

PDF_MANUAL = DATASET_DIR / "Manual_DPCA_atualizado.pdf"
PDF_LAUDO  = DATASET_DIR / "Laudo-Minimal.pdf"

print("="*60)
print("Datasets PDF da Aula 2")
print("="*60)
print(f"Dataset dir: {DATASET_DIR}")
print(f"  • Manual_DPCA_atualizado.pdf existe? {PDF_MANUAL.exists()}")
print(f"  • Laudo.pdf                  existe? {PDF_LAUDO.exists()}")

# Variáveis usadas pelas células seguintes (mantemos os nomes históricos)
# acordao_simples.pdf       → Manual_DPCA_atualizado.pdf  (digital)
# relatorio_inteligencia.pdf → Laudo.pdf                   (com OCR)
caminho_pdf_simples  = str(PDF_MANUAL) if PDF_MANUAL.exists() else None
caminho_pdf_complexo = str(PDF_LAUDO)  if PDF_LAUDO.exists()  else None

if caminho_pdf_simples is None or caminho_pdf_complexo is None:
    print("\n⚠️  Algum PDF do dataset não foi encontrado. Gerando fallback sintético...")
    
    # Fallback mínimo para quem rodar o notebook sem os PDFs reais
    from reportlab.lib.pagesizes import A4
    from reportlab.lib.styles import getSampleStyleSheet
    from reportlab.platypus import SimpleDocTemplate, Paragraph

    styles = getSampleStyleSheet()
    if caminho_pdf_simples is None:
        caminho_pdf_simples = "/tmp/fallback_simples.pdf"
        SimpleDocTemplate(caminho_pdf_simples, pagesize=A4).build([
            Paragraph("ACÓRDÃO Nº 1234/2025 - HABEAS CORPUS", styles["Heading1"]),
            Paragraph("Fallback gerado porque Manual_DPCA não foi encontrado.", styles["Normal"]),
        ])
    if caminho_pdf_complexo is None:
        caminho_pdf_complexo = "/tmp/fallback_complexo.pdf"
        SimpleDocTemplate(caminho_pdf_complexo, pagesize=A4).build([
            Paragraph("LAUDO PERICIAL", styles["Heading1"]),
            Paragraph("Fallback gerado porque Laudo.pdf não foi encontrado.", styles["Normal"]),
        ])

print(f"\n✓ caminho_pdf_simples  = {caminho_pdf_simples}")
print(f"✓ caminho_pdf_complexo = {caminho_pdf_complexo}")
print("\nNOTA: o caminho_pdf_complexo (Laudo.pdf) é um PDF escaneado → precisa OCR.")
print("       A célula que processa esse PDF habilita do_ocr=True.")
# Out:
# ============================================================
# Datasets PDF da Aula 2
# ============================================================
# Dataset dir: /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/aula-02/datasets
#   • Manual_DPCA_atualizado.pdf existe? True
#   • Laudo.pdf                  existe? True
#
# ✓ caminho_pdf_simples  = /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/aula-02/datasets/Manual_DPCA_atualizado.pdf
# ✓ caminho_pdf_complexo = /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/aula-02/datasets/Laudo-Minimal.pdf
#
# NOTA: o caminho_pdf_complexo (Laudo.pdf) é um PDF escaneado → precisa OCR.
#        A célula que processa esse PDF habilita do_ocr=True.

# %% [markdown]
# ---
# ## 📉 Célula 3 — Extração com PyPDF2 (Baseline)
#
# Antes de ver o Docling, vamos estabelecer o **baseline** com PyPDF2 para ter uma comparação justa.

# %%
# ============================================================
# PYPDF2: Extração básica (baseline para comparação)
# ============================================================
import PyPDF2

def extrair_pypdf2(caminho_pdf):
    """Extrai texto de um PDF usando PyPDF2."""
    with open(caminho_pdf, 'rb') as arquivo:
        reader = PyPDF2.PdfReader(arquivo)
        textos = []
        for i, pagina in enumerate(reader.pages):
            texto = pagina.extract_text()
            textos.append({
                "pagina": i + 1,
                "texto": texto,
                "chars": len(texto) if texto else 0
            })
    return textos

# Testando em ambos os PDFs
print("📉 PYPDF2 — EXTRAÇÃO BASELINE")
print("="*60)

print("\n[1] Acórdão Simples:")
resultado_simples = extrair_pypdf2(caminho_pdf_simples)
for pag in resultado_simples:
    print(f"  Página {pag['pagina']}: {pag['chars']} caracteres")
    print(f"  Amostra: {pag['texto'][:300].strip()!r}")

print("\n[2] Relatório de Inteligência (com tabela):")
resultado_complexo = extrair_pypdf2(caminho_pdf_complexo)
for pag in resultado_complexo:
    print(f"  Página {pag['pagina']}: {pag['chars']} caracteres")
    print(f"  Amostra: {pag['texto'][:500].strip()!r}")

print()
print("⚠️  OBSERVE: A tabela de estatísticas foi extraída como texto")
print("   confuso, sem preservar a estrutura linha × coluna.")
# Out:
# 📉 PYPDF2 — EXTRAÇÃO BASELINE
# ============================================================
#
# [1] Acórdão Simples:
#   Página 1: 150 caracteres
#   Amostra: 'MANUAL  \nPARA USO DO PROTOCOLO DE POLÍCIA JUDICIÁRIA PARA DEPOIMENTO \nESPECIAL DE CRIANÇA E ADOLESCENTE  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nABRIL /2019'
#   Página 2: 1122 caracteres
#   Amostra: '2 \n \n \nDiretor Geral da Polícia Civil do Distrito Federal:  \nDelegado de Polícia Robson Cândido da Silva  \n \nDiretor  do Departamento de Polícia  Especializada:  \nDelegado  de Polícia  Victor Dan de Alencar Alves  \n \nDelegada Chefe da Delegacia Especial  de Proteção  à Criança e ao Adolescente'
#   Página 3: 3071 caracteres
#   Amostra: '3 \nSumário  \n \n1. Apresentação……………………………………………………… .…………….. ......4 \n2. Introdução Geral………………………………………………… .………………. ......5 \n3. A Polícia Judiciária e a Delegacia de Proteção à Criança e ao Adolescente  (DPCA) \n…………………………………………………………….................................... .......7 \n4. Postura'
#   Página 4: 2383 caracteres
#   Amostra: '4 \n1. APRESENTAÇÃ O \n \nNo esteio das disposições insertas na Convenção dos Direitos da Criança, da qual o \nBrasil é signatário, por força do Decreto nº 99.710, de 21 de novembro de 1990, cujos termos \ngarantem a toda e qualquer criança e adolescente, dentre outros direitos, o d e exprimir \nliv'
#   Página 5: 2279 caracteres
#   Amostra: '5 \n2. INTRODUÇÃO GERAL  \nA violência sexual contra crianças e adolescentes se apresenta como uma das mais \ncruéis formas de violações de direitos. Para Faleiros  (2000), tal violência deve ser entendida \ncomo uma situação de extrapolação de limites diversos : de direitos humanos, legais, de \np'
#   Página 6: 1306 caracteres
#   Amostra: '6 \nOs participantes, em sua maioria , relataram características negativas tanto para sua s \nconcepções de figura feminina, quanto masculina. A figura do homem foi descrita como um \nser forte e dominador, com necessidades de realizar algo ruim e a mulher como uma figura \nprotetora, mas ao mesmo'
#   Página 7: 2449 caracteres
#   Amostra: '7 \n \n3. A POLÍCIA JUDICIÁRIA E A DELEGACIA DE PROTEÇÃO À \nCRIANÇA E AO ADOLESCENTE  \nA Polícia Judiciária possui import ante papel no combate aos mais diversos tipos de \nviolação de direitos praticados em desfavor de crianças e adolescentes, uma vez que nas \natribuições constitucionalmente def'
#   Página 8: 2337 caracteres
#   Amostra: '8 \nAdolescentes – SDA, cujos  agentes de polícia a par de suas formações em áreas do \ncomportamento humano (psicologia, psicopedagogia , psicanálise  e pedagogia), possuem \nvasta experiência em investigação policial e em coleta de relatos de crianças e adolescentes \nvítimas e testemunhas de vi'
#   Página 9: 328 caracteres
#   Amostra: '9 \n \nAssim, o presente manual busca oferecer um norteamento para uso do protoc olo, \ndando a este o subsídio teórico e informativo necessário para uma melhor prática de oitiva . A \nseguir são apresentados alguns temas importantes para sua utilização  bem como algumas  \norientações para cada um'
#   Página 10: 2100 caracteres
#   Amostra: '10 \n4. POSTURA EXIGIDA AO POLICIAL RESPONSÁVEL PELA OITIVA  \nInicialmente, são exigidos comportamentos imprescindíveis para uma oitiva que \ngaranta proteção integral à criança/adolescente em todos os sentidos. Para tanto, é necessário \nque o policial responsável apresente -se com as diversas p'
#   Página 11: 1501 caracteres
#   Amostra: '11 \n \n5. CARACTERÍSTICAS A SEREM OBSERVADAS NA CRIANÇA/ADOLESCENTE \nPARA ADAPT AÇÃO DA OITIVA  \nHá uma série de comportamentos e características que podem ser observados ao longo \nda oitiva, ou antes mesmo pelos dados de encaminhamento, que podem orientar o policial \nresponsável pela oitiva a'
#   Página 12: 2430 caracteres
#   Amostra: '12 \n6. AVALIAÇÃO DA MEMÓRIA  \nA memória foi uma das primeiras faculdades humanas a serem estudadas pela \npsicologia experimental. Os primeiros estudos foram feitos pelo psicólogo alemão Herman \nEbbing haus (1850 -1909) que iniciou suas pesquisas em busca do que chamou de “memória \npura”, propo'
#   Página 13: 1711 caracteres
#   Amostra: '13 \nEm nosso contexto, o treino de memória episódica é fundamental  para a construção \nde um Depoimento Especial. Esse treino irá pr eparar a criança ou o adolescente para um \nrelato que é um pouco diferente do que estão acostumados em seu  cotidiano. Acontece que \npara o Depoimento Especial r'
#   Página 14: 1054 caracteres
#   Amostra: '14 \n \n7. ANÁLISE DO DESENVOLVIMENTO LINGUÍSTICO  \nAlém da avaliação da memória, deve -se realizar uma análise do repertório linguístico \nda criança/adolescente. Esta análise pode contribuir para adequar a interação verbal e o \nvocabulário empregado pelo policial r esponsável pela oitiva. Sendo'
#   Página 15: 2085 caracteres
#   Amostra: '15 \n \n8. OS ELEMENTOS E O AMBIENTE D E OITIVA  \n8.1. Espaço Pessoal  \nAlguns protocolos de entrevista forense com crianças chamam atenção em relação à \ndisposição do entrevistador  no ambiente de escuta  (HOME OFFICE , 2002; Y UILLE , 2002). \nA garantia do espaço pessoal da criança e do adoles'
#   Página 16: 2315 caracteres
#   Amostra: '16 \nque sejam escolhidos como forma de facilitar a interação en tre o policial e a vítima e até \nmesmo, em alguns casos, funcionar como instrumento  da narrativa (Ex: uma casa de bonecas \nque a criança pode utilizar para contar e contextualizar uma situação de violência). Excesso \nde brinquedo'
#   Página 17: 2381 caracteres
#   Amostra: '17 \nvolatilidade da memória)  e diante de situações de risco para a criança/adolescente  \n(Ex: casos em que a revelação é recente e a vítima re sida com o agressor ). \n8.4. Facilitação  \nEm muitos casos o policial pode se ver em uma situação desafiadora, com pouca \nabertura ou dificuldade para'
#   Página 18: 1072 caracteres
#   Amostra: '18 \nem revelar, falar de outros assuntos da vida da criança, brincar ou procurar relaxá -la \npara depois voltar ao assunto por meio de perguntas distintas . Saber o motivo da \nresistência e conscientizar a criança ou adolescente sobre a importância do relato , \nespecialmente em casos, por exem'
#   Página 19: 1426 caracteres
#   Amostra: '19 \n \n9. USO DE BONECOS ANATÔMICOS  \nNa literatura, existem divergências em relação à aceitação do uso dos bonecos \nanatômicos no contexto da entrevista fo rense. Por esta razão, o uso de bonecos anatômicos, \nbem como de desenhos e outros materiais  deve ser realizado com a devida competência,'
#   Página 20: 1888 caracteres
#   Amostra: '20 \n \n10. PERGUNTAS ADEQUADAS PARA A REALIZAÇÃO DA OITIVA  \n10.1. Tipos de Perguntas  \nUm dos principais objetivos da oitiva é realizar questionamentos à \ncriança/adolescente sem condicionar suas respostas ou influenciá -las por algum grau de \ndesejabilidade ou vi és do policial responsável. P'
#   Página 21: 1662 caracteres
#   Amostra: '21 \nA tabela abaixo expõe sugestões de perg untas apropriadas a depender da idade, \nconsiderando a transição de um raciocínio con creto a um abstrato. Por exemplo, para crianças \nde 4 anos é possível perguntar “quem”, “o que”, “onde” , “esse evento aconteceu uma ou mais \nde uma vez ”. Já um a'
#   Página 22: 1089 caracteres
#   Amostra: '22 \nreconhecimento ou a escolha de detalhes sobre o abuso que não foram mencionados” (Júnior \n& Torres, p. 65, 2013). Exemplos: “Ele(a) te levou para o quarto, não é?”, “Ele (a) tocou por \ndebaixo da roupa?”, “Mas não aconteceu nada dep ois, né?”.  \n10.4. Perguntas que devem ser evitadas  \na)'
#   Página 23: 1721 caracteres
#   Amostra: '23 \n \n11. DEMAIS OBSERVAÇÕES  \n \na) Constitui crime - previsto no A rt. 24 da L ei 13.431 /2017  - permitir que o \ndepoimento especial de criança ou adolescente seja assistido por pessoa estranha \nao processo, sem autorização judicial e sem o consentiment o do depoente ou de \nseu representante'
#   Página 24: 2410 caracteres
#   Amostra: '24 \n12. CASOS DE RETRATAÇÃO E ALIENAÇÃO PARENTAL: IDENTIFICAÇÃO E \nESTRATÉGIAS  \n \n12.1. Retratação  \nTendo em vista a diversidade de complicadores enco ntrados na coleta do Depoimento \nEspecial de crianças e adolescentes vítimas de abuso, percebe -se que é necessário um \nconhecimento prévio s'
#   Página 25: 2078 caracteres
#   Amostra: '25 \ncomo: novas ameaças do abusador, o medo de represálias, a culpa, a separação da família, o \nsofrimento dos pais ou  a possibilidade de prisão do ofensor, que fazem a criança ficar confusa \nou arrependida de ter revelado o abuso.  Muitas vezes, para isso, tentará ocultar, corrigir, \ndeturpa'
#   Página 26: 1610 caracteres
#   Amostra: '26 \n“não lembro”, mesmo para questões muito óbvias ou que ocorreram há pouco \ntempo. A criança/ adolescente também pode apresentar verbalizações adequadas \naté o momento em  que o tema d a violência  vem à tona , mudando seu \ncomportamento. Assim, avaliando -se previamente se  a criança/adoles'
#   Página 27: 1803 caracteres
#   Amostra: '27 \n9. Estratégia : Explicar à criança/adolescente que ela tem  o direito de contar a sua \nhistória à sua maneira, mas ao mesmo tempo solicitar que a mesma expl ique o \nmotivo pelo qual está apresentando uma v ersão diferente para os fatos.  Estes \nmotivos podem estar sendo permeados por ameaç'
#   Página 28: 1929 caracteres
#   Amostra: '28 \num raciocínio sequencial em sua narrativa. A criança/adolescente podem \nimediatamente começar o Depoimento relatando que sofreu abuso ou outra violação \npor parte de algum familiar ; \n- A fala da criança/adole scente é permeada de informações exageradamente \ndepreciativas sobre um determin'
#   Página 29: 445 caracteres
#   Amostra: '29 \nou provocar um determinado relato. Tais considerações devem vir apenas no relatório \nposterior ao depoimento a ser elaborado pelo responsá vel pelo mesmo . \nRessalte -se que  não é possível determinar se tais condições  vão estar presentes  antes \nde ouvir a criança/adolescente. Por isso é'
#   Página 30: 1855 caracteres
#   Amostra: '30 \n \n13. INSTRUÇÕES PARA USO DO PROTOCOLO  \n \nO presente protocolo oferece a oportunidade de uma oitiva dinâmica, porém , para a \ngarantia de uma condução eficaz, é necessário a passagem por oito etapas essenciais  \naplicáveis a crianças e/ou adolescentes, conforme o caso.  \nInicialmente, é r'
#   Página 31: 19 caracteres
#   Amostra: '31'
#   Página 32: 1470 caracteres
#   Amostra: '32 \n \n \nFase 1: A presentação  \nO objetivo desta fase é apresentar a sala, o policial responsável e a criança/adolescente, além de  \ncientificá -la acerca da gravação em áudio e vídeo .  \nOrientações  \n1. Indica -se um ambiente confortável, acolhedor, sem ruídos e privado para realização da \no'
#   Página 33: 1766 caracteres
#   Amostra: '33 \nConsidera ções \n1. Para a observação das condições físicas da criança ou adolescente, de acordo com o item \n1.3 do Protocolo , em momento nenhu m serão retirad as as vestes daquela. Em casos em \nque a criança queira retirar as vestimentas para mostrar algo, diga , gentilmente,  que não \né'
#   Página 34: 2044 caracteres
#   Amostra: '34 \nalguma coisa que não deveria ter ocorrido, que o (a) incomodou de alguma forma ; \n2. Se ainda assim  o adolescente  negar . Faça perguntas que auxiliem  a suposta vítima a falar \nsobre os fatos circundantes da notícia -crime  (lugares, testemunhas ou situações) , sem,  no \nentanto, mencion'
#   Página 35: 1679 caracteres
#   Amostra: '35 \n \nTransição  \nÉ a fase de explicação sobre a delegacia. Neste caso, se a criança/adolescente so uber o motivo \npelo qual compareceu, avançar para a próxima fase (Relato Livre Sobre o Fato em Apuração ). \nCaso contrário, realize as questões de transição.  \nOrientações  \n1. Embora seja um mo'
#   Página 36: 1947 caracteres
#   Amostra: '36 \nmaterno. Os questionamento s devem levar suavemente o assunto até o local e as \ncircunstâncias da violação , sem mencionar nenhum destes aspectos diretamente, \ndeixando que a vítima o aborde espontaneamente sem qualquer espécie de \nindução;  \n1.3 O policial condutor da oitiva poderá também'
#   Página 37: 1947 caracteres
#   Amostra: '37 \nFase 5: Relato Livre sobre o fato em apuração.  \nÉ a narrativa livre da criança ou adolescente sobre os fatos em apuração.  \nObservação  \n1. Durante esta fase, o policial responsável pela oitiva NÃO poderá interromper a fala da \ncriança /adolescente .  \n \nFase 6: Questões Pertinentes à Inv'
#   Página 38: 2031 caracteres
#   Amostra: '38 \nObservações essenciais :  \n1. As questões referentes a essa  fase devem ser adequad as à necessidade e relevância do \ncaso, além de serem aj ustad as ao nível de compreensão da criança/adolescente ; \n2. Caso, a criança /adolescente  não mencione, durante o relato livre, o fato noticiado, e'
#   Página 39: 1092 caracteres
#   Amostra: '39 \nFase 7: Fechamento  \nOs objetivos desta fase são agradecer a disponibilidade em comparecer  na delegacia  e \nesclarecer as possíveis dúvidas da criança/adolescente . Além disso, é o momento no qual  o \npolicial responsável irá avaliar a possibilidade e nece ssidade de encaminhamento  da re'
#   Página 40: 1278 caracteres
#   Amostra: '40 \n \n14. UTILIZAÇÃO DO PROTOCOLO EM GERAL  \n \n \nEmbora uma maior ênfase tenha sido dada  até este momento em casos cuja \ninvestigação versa sobre violência sexual e maus tratos, o presente protocolo deve ser \nutilizado em situaç ões de violações diver sas, tanto para crianças e adolescentes a'
#   Página 41: 1546 caracteres
#   Amostra: '41 \n \n15. ACESSO A OUTROS PROTOCOLOS DE REFE RÊNCIA  \n \n1. Entrevista Passo a Passo: \nhttps://redengine.lawsociety.sk.ca/inmagicgenie/documentfolder/ac2062.pdf  \n2. Protocolo NICHD: http://nichdprotocol.com/nichdbrazil.pdf  \n3. Protocolo NCAC: http://www.chicagocac.org/wp -content/uploads/2015'
#   Página 42: 2227 caracteres
#   Amostra: '42 \n \n16. REFERÊNCIAS  \n \nBRASIL. Lei nº 12.318, de  26 de agosto de 2010. Altera o artigo 236 do Estatuto da Criança \ne do Adolescente  \n \nBRASIL. Lei nº 13.431, de 4 de abril de 2017. Estabelece o sistema de garantia de direitos da \ncriança e do adolescente vítima ou testemunha de violência'
#   Página 43: 1499 caracteres
#   Amostra: "43 \nALVES JÚNIOR , Reginaldo  Torres . Um sistema de análise de entrevistas forenses com \ncrianças em casos de suspeita de abuso sexual. 2013.  \nLURIA, Aleksandr  Romanovich. Atención y memoria . Fontanella, 1979.  \nO'SHEA, Michael. The brain: A very short introduction . OUP Oxford, 2005.  \nPI"
#   Página 44: 29 caracteres
#   Amostra: '44'
#   Página 45: 3639 caracteres
#   Amostra: '45 \n \n16.Dados sobre os colaboradores  \nAna Cristin a Melo Santiago: Delegada de Polícia desde o ano de 1996, Especialista em \nSegurança Pública e Política Criminal e Penitenciária pela UNIRIO, com atuação em diversas \nunidades da Polícia Civil e da Secr etaria de Estado de Segurança Pú blica'
#   Página 46: 3273 caracteres
#   Amostra: '46 \nhonrosas por trabalhos publicados em congressos científicos  e é pesquisador vinculado ao \nLabor atório de Psicologia Ambiental, Laboratório de Avaliação e Medidas e Grupo \nInfluência do Laboratório de Psicologia Social.  Possui experiência clínic a, como estagiário, \nem Terapia Cognitiva'
#
# [2] Relatório de Inteligência (com tabela):
#   Página 1: 1901 caracteres
#   Amostra: 'PREFEITURA MUNICIPAL DE JAPURÁ — LAUDO DE INSALUBRIDADE E PERICULOSIDADE 58 \nTÉCNICO EM HIGIENE DENTAL \nSETOR EM QUE EXERCE SUAS ATIVIDADES Departamento de Saúde — Consultório Dentário- NISI \nATIVIDADES DESENVOLVIDAS \n* Atuar em consultório dentário, preparando os pacientes para atendimento, instrumentando o Cirurgião Dentista e manipulando materiais restauradores. * Selecionar moldeiras e confeccionar Modelos em gesso, conforme orientação do Cirurgião Dentista, \n* Marcar consultas, preencher e'
#   Página 2: 2098 caracteres
#   Amostra: 'PREFEITURA MUNICIPAL DE JAPURÁ — LAUDO DE INSALUBRIDADE E PERICULOSIDADE 76 \nOPERADOR DE MÁQUINAS \nSETOR EM QUE EXERCE SUAS ATIVIDADES \nDepartamento Obras e Viações. \nATIVIDADES DESENVOLVIDAS \ne Operar máquinas e equipamentos pesados, realizando trabalhos de terraplanagem, aterros, nivelamento e revestimento de estradas, desmatamento, abertura e desobstrução de valetas, nivelamento de terrenos é taludes, remoção e compactação de terra. e Relatar, em caderneta de registros, Os serviços executados'
#   Página 3: 1980 caracteres
#   Amostra: 'PREFEITURA MUNICIPAL DE JAPURÁ — LAUDO DE INSALUBRIDADE E PERICULOSIDADE ” \n  \n      \n  \n  \n  \n  \n  PÁ CAREGADEIRA Máxima exposição permitida (NR \n(cabine fechada) Caterpillar 930 T 15 = Anexo 1) \nPressão sonora (dB(A)) 90 a 95 4 horas a 2 horas \nPÁ CAREGADEIRA Máxima exposição permitida (NR \n(cabine fechada) Co Wo E 15 —- Anexo 1) \nPressão sonora (dB(A)) 85,5 a 90,6 7 horas a 3 horas e 30 minutos \nMOTONIVELADORA a Máxima exposição permitida (NR \n(cabine fechada) Emterpilar 15 - Anexo 1) \ndB(A)'
#   Página 4: 1566 caracteres
#   Amostra: '(rejusurepuny ouIsug) \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n            teagonde \no8N \nEPEZUSJDBILO \nOEN \npagode \noBN \nEPEZLISJIBIPO \nOEN \n| \n OANBISIUIIPY \nIempany \n6 (BQUIZOD) \nSIBISL) feapoide \ncgN \nEPEZUSJIRIBO \nOEN \nEpEZIjEmNoU \nCOEN \nEPEZLISJDBIPO \nOEN \nSOSIAIIS \nap \nJENNY \n*g (ezodurT) \nsrBiar) pagode \n0BN \nEPEZIIIJIEIES \nOEN \nEpezIJEnnoU \nOEN \nBPEZIISJDBIBO \nOBN \nSOSIAISS \n9P \nJEIIXTY \n"L [eapolde \noeN \nEPEZLISJIBIBO \nOEN \nEpeZI[Egnau \nOEN \nEPEZLIS]JDBIES \n0EN \nJOSSaJ \nOI] \n\'Q [pagode \n0E'
#
# ⚠️  OBSERVE: A tabela de estatísticas foi extraída como texto
#    confuso, sem preservar a estrutura linha × coluna.

# %% [markdown]
# ---
# ## 🚀 Célula 4 — Extração com Docling (Tutorial Passo a Passo)
#
# ### Arquitetura do Docling
#
# ```
# PDF Input
#     │
#     ▼
# ┌─────────────────────────────────────────────┐
# │            DocumentConverter                │
# │  ┌─────────────┐    ┌────────────────────┐  │
# │  │ PDF Backend │───▶│  Pipeline Steps:   │  │
# │  │(pypdfium2)  │    │  1. Layout Analysis│  │
# │  └─────────────┘    │  2. Table Structure│  │
# │                     │  3. OCR (opcional) │  │
# │                     │  4. Reading Order  │  │
# │                     └────────────────────┘  │
# └─────────────────────────────────────────────┘
#     │
#     ▼
# DoclingDocument
#     │
#     ├── .export_to_markdown()   → Markdown estruturado
#     ├── .export_to_dict()       → JSON estruturado
#     └── .tables                 → Tabelas extraídas
# ```

# %%
# ============================================================
# PASSO 1: Importar e configurar o DocumentConverter (Docling v2.x)
# ============================================================
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import PdfPipelineOptions

# 1. Configuração específica para PDFs
pipeline_options = PdfPipelineOptions()
pipeline_options.do_ocr = False              # False: mais rápido para PDFs com texto nativo
pipeline_options.do_table_structure = True   # ESSENCIAL para extrair tabelas

print("⏳ Inicializando Docling...")
print("   (Pode demorar 1–2 min para baixar modelos na primeira execução)")

# 2. Inicializa o DocumentConverter mapeando o formato PDF para suas opções correspondentes
converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_options=pipeline_options
        )
    }
)

print("✅ Docling inicializado com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 4
#       1 # ============================================================
#       2 # PASSO 1: Importar e configurar o DocumentConverter (Docling v2.x)
#       3 # ============================================================
# ----> 4 from docling.document_converter import DocumentConverter, PdfFormatOption
#       5 from docling.datamodel.base_models import InputFormat
#       6 from docling.datamodel.pipeline_options import PdfPipelineOptions
#
# File ~/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages/docling/document_converter.py:68
#      61 from docling.datamodel.settings import (
#      62     DEFAULT_PAGE_RANGE,
#      63     DocumentLimits,
#      64     PageRange,
#      65     settings,
#      66 )
#      67 from docling.exceptions import ConversionError
# ---> 68 from docling.pipeline.asr_pipeline import AsrPipeline
#      69 from docling.pipeline.base_pipeline import BasePipeline
#      70 from docling.pipeline.simple_pipeline import SimplePipeline
#
# File ~/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages/docling/pipeline/asr_pipeline.py:33
#      26 from docling.datamodel.pipeline_options import (
#      27     AsrPipelineOptions,
#      28 )
#      29 from docling.datamodel.pipeline_options_asr_model import (
#      30     InlineAsrMlxWhisperOptions,
#      31     InlineAsrNativeWhisperOptions,
#      32 )
# ---> 33 from docling.pipeline.base_pipeline import BasePipeline
#      34 from docling.utils.accelerator_utils import decide_device
#      35 from docling.utils.profiling import ProfilingScope, TimeRecorder
#
# File ~/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages/docling/pipeline/base_pipeline.py:36
#      34 from docling.models.factories import get_picture_description_factory
#      35 from docling.models.picture_description_base_model import PictureDescriptionBaseModel
# ---> 36 from docling.models.stages.chart_extraction.granite_vision import (
#      37     ChartExtractionModelGraniteVision,
#      38     ChartExtractionModelGraniteVisionV4,
#      39 )
#      40 from docling.models.stages.picture_classifier.document_picture_classifier import (
#      41     DocumentPictureClassifier,
#      42 )
#      43 from docling.utils.profiling import ProfilingScope, TimeRecorder
#
# File ~/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages/docling/models/stages/chart_extraction/granite_vision.py:27
#      25 from PIL import Image
#      26 from pydantic import BaseModel
# ---> 27 from transformers import AutoModelForImageTextToText, AutoProcessor
#      29 from docling.datamodel.accelerator_options import AcceleratorDevice, AcceleratorOptions
#      30 from docling.datamodel.base_models import ItemAndImageEnrichmentElement
#
# File ~/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages/transformers/__init__.py:27
#      24 from typing import TYPE_CHECKING
#      26 # Check the dependencies satisfy the minimal versions required.
# ---> 27 from . import dependency_versions_check
#      28 from .utils import (
#      29     OptionalDependencyNotAvailable,
#      30     _LazyModule,
#    (...)     36     is_pretty_midi_available,
#      37 )
#      39 # Note: the following symbols are deliberately exported with `as`
#      40 # so that mypy, pylint or other static linters can recognize them,
#      41 # given that they are not exported using `__all__` in this file.
#
# File ~/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages/transformers/dependency_versions_check.py:57
#      54         if not is_accelerate_available():
#      55             continue  # not required, check version only if installed
# ---> 57     require_version_core(deps[pkg])
#      58 else:
#      59     raise ValueError(f"can't find {pkg} in {deps.keys()}, check dependency_versions_table.py")
#
# File ~/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages/transformers/utils/versions.py:117, in require_version_core(requirement)
#     115 """require_version wrapper which emits a core-specific hint on failure"""
#     116 hint = "Try: `pip install transformers -U` or `pip install -e '.[dev]'` if you're working with git main"
# --> 117 return require_version(requirement, hint)
#
# File ~/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages/transformers/utils/versions.py:111, in require_version(requirement, hint)
#     109 if want_ver is not None:
#     110     for op, want_ver in wanted.items():
# --> 111         _compare_versions(op, got_ver, want_ver, requirement, pkg, hint)
#
# File ~/PycharmProjects/mba-ia/07-rag-cag/venv_rag/lib/python3.11/site-packages/transformers/utils/versions.py:44, in _compare_versions(op, got_ver, want_ver, requirement, pkg, hint)
#      39     raise ValueError(
#      40         f"Unable to compare versions for {requirement}: need={want_ver} found={got_ver}. This is unusual. Consider"
#      41         f" reinstalling {pkg}."
#      42     )
#      43 if not ops[op](version.parse(got_ver), version.parse(want_ver)):
# ---> 44     raise ImportError(
#      45         f"{requirement} is required for a normal functioning of this module, but found {pkg}=={got_ver}.{hint}"
#      46     )
#
# ImportError: huggingface-hub>=0.34.0,<1.0 is required for a normal functioning of this module, but found huggingface-hub==1.6.0.
# Try: `pip install transformers -U` or `pip install -e '.[dev]'` if you're working with git main

# %%
# ============================================================
# PASSO 2: Converter o PDF digital (Manual_DPCA_atualizado.pdf)
# ============================================================
import time
from pathlib import Path

print(f"🔄 Convertendo: {caminho_pdf_simples}")
inicio = time.time()

# convert() retorna um ConversionResult
result_acordao = converter.convert(caminho_pdf_simples)

tempo = time.time() - inicio
print(f"✅ Conversão concluída em {tempo:.2f}s")

# Exportando para Markdown estruturado
markdown_acordao = result_acordao.document.export_to_markdown()

print()
print("📝 OUTPUT DOCLING — Manual_DPCA em Markdown (primeiros 1500 chars):")
print("="*60)
print(markdown_acordao[:1500])
print("[...]")

print(f"\n📊 Estatísticas:")
print(f"   • Tamanho do Markdown: {len(markdown_acordao)} chars")
# 1. Conta todos os itens de texto do documento (parágrafos, títulos, itens de lista, etc.)
print(f"   • Elementos de texto detectados: {len(result_acordao.document.texts)}")
# 2. Conta a quantidade de tabelas mapeadas
print(f"   • Tabelas: {len(result_acordao.document.tables)}")
# Out:
# 🔄 Convertendo: /Users/gustavoaranha/PycharmProjects/mba-ia/07-rag-cag/aula-02/datasets/Manual_DPCA_atualizado.pdf
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 11
#       8 inicio = time.time()
#      10 # convert() retorna um ConversionResult
# ---> 11 result_acordao = converter.convert(caminho_pdf_simples)
#      13 tempo = time.time() - inicio
#      14 print(f"✅ Conversão concluída em {tempo:.2f}s")
#
# NameError: name 'converter' is not defined

# %%
import os
import time
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import PdfPipelineOptions, EasyOcrOptions
from docling.backend.pypdfium2_backend import PyPdfiumDocumentBackend

# --- NOVO: Importar as opções do acelerador ---
from docling.datamodel.accelerator_options import AcceleratorOptions, AcceleratorDevice

# 1. Definir quantas threads você quer (ex: total de núcleos da sua CPU)
num_nucleos = os.cpu_count() or 4 

# 2. Configurar o acelerador para a CPU usando as threads
config_acelerador = AcceleratorOptions(
    num_threads=num_nucleos,
    device=AcceleratorDevice.CPU # Força o uso correto da CPU no Windows
)

# 3. Configurar o OCR reduzindo o idioma para acelerar
ocr_options = EasyOcrOptions(
    lang=["pt"], 
    force_full_page_ocr=True
)

# 4. Juntar tudo nas opções do Pipeline do PDF
pipeline_options_ocr = PdfPipelineOptions(
    do_ocr=True,
    ocr_options=ocr_options,
    do_table_structure=False,      # Desative se não precisar de tabelas perfeitas (ganha muita velocidade)
    accelerator_options=config_acelerador # ← AS THREADS ENTRAM AQUI!
)

# 5. Inicializar o DocumentConverter de forma limpa (sem num_threads aqui)
converter_ocr = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(
            pipeline_options=pipeline_options_ocr,
            backend=PyPdfiumDocumentBackend
        ),
    }
)

# %%
# ============================================================
# PASSO 3: Converter o PDF escaneado (Laudo.pdf — IMAGEM DE TEXTO)
# Este caso REQUER OCR (do_ocr=True). É onde o Docling brilha contra o PyPDF2.
# ============================================================

DATASET_DIR = Path("../datasets").resolve()
if not DATASET_DIR.exists():
    DATASET_DIR = Path.cwd().parent / "datasets"

PDF_LAUDO  = DATASET_DIR / "Laudo-Minimal.pdf"
caminho_pdf_complexo = str(PDF_LAUDO)  if PDF_LAUDO.exists()  else None


print(f"🔄 Convertendo: {caminho_pdf_complexo}")
print("   Este PDF é escaneado (imagem de texto) — habilitando do_ocr=True.")
print("   ⏳ Pode levar 30s–3min dependendo do número de páginas e CPU.")


inicio = time.time()
try:
    result_relatorio = converter_ocr.convert(caminho_pdf_complexo)
    tempo = time.time() - inicio
    print(f"✅ Conversão (com OCR) concluída em {tempo:.2f}s")

    markdown_relatorio = result_relatorio.document.export_to_markdown()

    print()
    print("📝 OUTPUT DOCLING — Laudo.pdf em Markdown (primeiros 2000 chars):")
    print("="*60)
    print(markdown_relatorio[:2000])
    print("[...]")
    print()
    
    # --- CORREÇÃO DA V2 AQUI ---
    # Pegamos a estrutura v2 do documento carregado
    doc_estrutura = result_relatorio.document
    
    # Contamos os elementos usando o iterador oficial da biblioteca
    total_elementos = len(list(doc_estrutura.iterate_items()))
    total_tabelas = len(doc_estrutura.tables)
    
    print(f"📊 Estatísticas:")
    print(f"   • Tamanho do Markdown:  {len(markdown_relatorio)} chars")
    print(f"   • Elementos detectados: {total_elementos}")
    print(f"   • Tabelas detectadas:    {total_tabelas}")
    print()
    print("🎯 OBSERVE: o Docling RECONSTRUIU texto a partir de uma imagem!")
except Exception as e:
    print(f"\n❌ Erro no processamento OCR: {e}")
    print("   • Verifique se EasyOCR foi baixado (1ª execução demora)")
    print("   • Em máquinas sem GPU, OCR é dezenas de vezes mais lento")
    result_relatorio = None
    markdown_relatorio = ""

# %%
# ============================================================
# PASSO 4: Acessando elementos estruturados do documento
# O DoclingDocument é um objeto rico — muito mais que texto plano
# ============================================================
print("🏗️ ESTRUTURA DO DOCLING DOCUMENT")
print("="*60)

doc = result_relatorio.document

# Iterando pelos elementos do documento com seus tipos
print("\n📋 Elementos identificados:")
contagem_tipos = {}
for elemento in doc.iterate_items():
    # elemento é uma tupla (item, level) em versões recentes do Docling
    item = elemento[0] if isinstance(elemento, tuple) else elemento
    tipo = type(item).__name__
    contagem_tipos[tipo] = contagem_tipos.get(tipo, 0) + 1

for tipo, count in sorted(contagem_tipos.items()):
    print(f"   {tipo}: {count}")

print()

# Acessando tabelas especificamente
print(f"📊 Tabelas identificadas: {len(doc.tables)}")
for i, tabela in enumerate(doc.tables):
    print(f"\nTabela {i+1}:")
    
    # Em vez de puxar propriedades que sumiram, extraímos direto para o DataFrame primeiro
    try:
        # Na v2, a forma recomendada de exportar para pandas é passando o documento base como contexto
        df_tabela = tabela.export_to_dataframe(doc)
        
        # Agora pegamos o tamanho real da tabela direto pelas dimensões do Pandas DataFrame (shape)
        linhas, colunas = df_tabela.shape
        print(f"   Linhas: {linhas}")
        print(f"   Colunas: {colunas}")
        print(f"   Preview:\n{df_tabela.to_string()}")
        
    except Exception as e:
        print(f"   (Erro ao exportar ou ler DataFrame: {e})")
        
        # Alternativa caso queira inspecionar as células brutas sem Pandas:
        # O dado bruto vive em tabela.data.table_cells
        try:
            print(f"   Label/Legenda da tabela: {tabela.caption}")
        except:
            pass

# %% [markdown]
# ---
# ## 🔄 Célula 5 — Comparação Docling vs PyPDF2
#
# Vamos quantificar as diferenças de forma objetiva:

# %%
# ============================================================
# COMPARAÇÃO QUANTITATIVA: PyPDF2 vs Docling
# ============================================================
import pandas as pd

# Extração PyPDF2
pypdf_resultado = extrair_pypdf2(caminho_pdf_complexo)
texto_pypdf = " ".join([p["texto"] for p in pypdf_resultado if p["texto"]])

# Extração Docling
texto_docling = markdown_relatorio

# Verificações qualitativas
def verifica_qualidade(texto, nome):
    verificacoes = {
        "Ferramenta": nome,
        "Total chars": len(texto),
        "Total palavras": len(texto.split()),
        "Tem 'RELATÓRIO'": 'RELATÓRIO' in texto.upper() or 'RELATORIO' in texto.upper(),
        "Tem 'ESTATÍSTICAS'": 'ESTATÍSTICAS' in texto.upper() or 'ESTATISTICAS' in texto.upper(),
        "Tem tabela (|)": '|' in texto,  # Markdown table indicator
        "Tem Headers (#)": '#' in texto,
        "Tem '113' (total tráfico)": '113' in texto,
        "Tem '11,8%' (variação)": '11,8%' in texto or '11.8%' in texto,
        "Tem seções identificadas": texto.count('\n## ') > 0 or texto.count('\n# ') > 0,
    }
    return verificacoes

qual_pypdf = verifica_qualidade(texto_pypdf, "PyPDF2")
qual_docling = verifica_qualidade(texto_docling, "Docling")

print("📊 COMPARAÇÃO QUALITATIVA: PyPDF2 vs Docling")
print("="*65)
print(f"{'Verificação':<35} {'PyPDF2':>10} {'Docling':>10}")
print("-"*55)

for chave in qual_pypdf:
    if chave == "Ferramenta":
        continue
    v_pypdf = qual_pypdf[chave]
    v_docling = qual_docling[chave]

    # Formata booleanos com emoji
    def fmt(v):
        if isinstance(v, bool):
            return "✅" if v else "❌"
        return str(v)

    print(f"  {chave:<33} {fmt(v_pypdf):>10} {fmt(v_docling):>10}")

print()
print("🏆 Conclusão: Docling preserva estrutura, tabelas e seções.")
print("   PyPDF2 só funciona bem para PDFs de texto simples.")

# %% [markdown]
# ---
# ## 🔗 Célula 6 — Integração Docling + LangChain
#
# O objetivo final é ter **LangChain Documents** prontos para indexação no FAISS/OpenSearch.

# %%
# ============================================================
# INTEGRAÇÃO: Docling → LangChain Documents
# ============================================================
# %pip install langchain-text-splitters langchain-core 
from langchain_core.documents import Document
from langchain_text_splitters import MarkdownHeaderTextSplitter, RecursiveCharacterTextSplitter
from pathlib import Path

def pdf_para_langchain_documents(caminho_pdf: str, metadados_extras: dict = None) -> list:
    """
    Pipeline completo: PDF → Docling → Markdown → Chunks LangChain.

    Args:
        caminho_pdf: Caminho para o arquivo PDF
        metadados_extras: Metadados adicionais a incluir em cada chunk

    Returns:
        Lista de LangChain Documents prontos para indexação
    """
    print(f"📄 Processando: {Path(caminho_pdf).name}")

    # PASSO 1: Converter PDF com Docling
    result = converter.convert(caminho_pdf)
    markdown_text = result.document.export_to_markdown()
    print(f"   ✓ Docling: {len(markdown_text)} chars extraídos")

    # PASSO 2: Chunking baseado em headers (Markdown)
    headers_split = [
        ("#", "Seção"),
        ("##", "Subseção"),
        ("###", "Item"),
    ]
    header_splitter = MarkdownHeaderTextSplitter(
        headers_to_split_on=headers_split,
        strip_headers=False
    )
    chunks_header = header_splitter.split_text(markdown_text)

    # PASSO 3: Para chunks ainda grandes, aplica recursive split
    rec_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000,
        chunk_overlap=150
    )

    documents_finais = []
    for chunk_doc in chunks_header:
        if len(chunk_doc.page_content) > 1200:
            # Chunk muito grande — subdividir
            sub_chunks = rec_splitter.split_text(chunk_doc.page_content)
            for j, sub in enumerate(sub_chunks):
                meta = chunk_doc.metadata.copy()
                meta["sub_chunk"] = j
                if metadados_extras:
                    meta.update(metadados_extras)
                meta["fonte"] = caminho_pdf
                meta["chars"] = len(sub)
                documents_finais.append(Document(page_content=sub, metadata=meta))
        else:
            meta = chunk_doc.metadata.copy()
            if metadados_extras:
                meta.update(metadados_extras)
            meta["fonte"] = caminho_pdf
            meta["chars"] = len(chunk_doc.page_content)
            documents_finais.append(Document(
                page_content=chunk_doc.page_content,
                metadata=meta
            ))

    print(f"   ✓ Chunks gerados: {len(documents_finais)}")
    return documents_finais


# Testando o pipeline completo em ambos os PDFs
docs_acordao = pdf_para_langchain_documents(
    caminho_pdf_simples,
    metadados_extras={"tipo": "acórdão", "tribunal": "TJSP", "ano": 2025}
)

docs_relatorio = pdf_para_langchain_documents(
    caminho_pdf_complexo,
    metadados_extras={"tipo": "relatório_inteligência", "orgao": "PC", "ano": 2025}
)

# Combinar todos os documentos
todos_docs = docs_acordao + docs_relatorio

print()
print(f"📚 Total de Documents prontos para indexação: {len(todos_docs)}")
print()
print("Amostra do primeiro Document:")
print(f"  Metadados: {todos_docs[0].metadata}")
print(f"  Conteúdo: {todos_docs[0].page_content[:200]!r}")

# %%
# ============================================================
# BÔNUS: PDFs Escaneados com OCR
# Demonstração de configuração (não executa OCR real aqui)
# ============================================================
print("🖥️ CONFIGURAÇÃO PARA PDFs ESCANEADOS (OCR)")
print("="*60)
print()
print("Para PDFs digitalizados (imagens), use:")
print()

codigo_ocr = '''
from docling.document_converter import DocumentConverter
from docling.datamodel.pipeline_options import PipelineOptions
from docling.backend.pypdfium2_backend import PyPdfium2DocumentBackend

# Configuração com OCR habilitado
pipeline_options = PipelineOptions(
    do_ocr=True,                    # ← Habilita OCR
    do_table_structure=True,
    ocr_options={
        "lang": ["pt", "en"],       # ← Idiomas para OCR
        "force_full_page_ocr": False # ← False: OCR só quando necessário
    }
)

converter_ocr = DocumentConverter(
    pipeline_options=pipeline_options
)

# Processar PDF escaneado
result = converter_ocr.convert("laudo_pericial_escaneado.pdf")
texto = result.document.export_to_markdown()
'''

print(codigo_ocr)
print("⚠️  OCR é ~10x mais lento que extração de texto nativo.")
print("   Use apenas quando necessário.")
print()
print("📌 Casos de uso no contexto jurídico:")
print("   - Boletins de ocorrência antigos (pré-2010)")
print("   - Laudos periciais digitalizados")
print("   - Processos físicos escaneados")
print("   - Contratos assinados manualmente e digitalizados")

# %%
# ============================================================
# BÔNUS: Processamento em Lote (múltiplos PDFs)
# Padrão comum em produção jurídica
# ============================================================
from pathlib import Path
from typing import List

def processar_pasta_pdfs(pasta: str, metadados_globais: dict = None) -> List:
    """
    Processa todos os PDFs de uma pasta em lote.

    Em produção, você pode adaptar para:
    - Processar em paralelo (concurrent.futures)
    - Cachear resultados já processados
    - Registrar erros em log
    """
    pasta_path = Path(pasta)
    pdfs = list(pasta_path.glob("*.pdf"))

    if not pdfs:
        print(f"⚠️ Nenhum PDF encontrado em: {pasta}")
        return []

    todos_documentos = []
    erros = []

    print(f"📂 Processando {len(pdfs)} PDFs...")

    for i, pdf_path in enumerate(pdfs, 1):
        print(f"[{i}/{len(pdfs)}] {pdf_path.name}")
        try:
            docs = pdf_para_langchain_documents(
                str(pdf_path),
                metadados_extras={**(metadados_globais or {}), "arquivo": pdf_path.name}
            )
            todos_documentos.extend(docs)
        except Exception as e:
            print(f"   ❌ Erro: {e}")
            erros.append({"arquivo": pdf_path.name, "erro": str(e)})

    print()
    print(f"✅ Processamento concluído:")
    print(f"   PDFs processados: {len(pdfs) - len(erros)}")
    print(f"   Erros: {len(erros)}")
    print(f"   Total de chunks: {len(todos_documentos)}")

    if erros:
        print(f"\n❌ Arquivos com erro:")
        for e in erros:
            print(f"   {e['arquivo']}: {e['erro']}")

    return todos_documentos


# Demonstração com a pasta /tmp
print("🔬 Teste do processamento em lote:")
docs_lote = processar_pasta_pdfs("/tmp")
print(f"\n📊 Total de Documents gerados: {len(docs_lote)}")

# %% [markdown]
# ---
# ## ✅ Resumo — Docling vs PyPDF2
#
# | Capacidade | PyPDF2 | Docling |
# |---|---|---|
# | Texto simples | ✅ Ótimo | ✅ Ótimo |
# | Tabelas | ❌ Ilegível | ✅ Estruturado |
# | Headers/Seções | ❌ Não detecta | ✅ Markdown |
# | PDFs escaneados | ❌ Vazio | ✅ Com OCR |
# | DOCX, PPTX, HTML | ❌ Não suporta | ✅ Suportado |
# | Velocidade | ⚡⚡⚡ Muito rápido | ⚡⚡ Moderado |
# | Instalação | `pip install PyPDF2` | `pip install docling` (+modelos) |
#
# **Quando usar PyPDF2:** PDFs de texto puro, alto volume, sem tabelas, sem estrutura.
#
# **Quando usar Docling:** PDFs com tabelas, estrutura de seções, PDFs escaneados, alta qualidade de extração necessária.
#
# **Próximo notebook:** `LAB1_Naive_RAG_Juridico.ipynb`
